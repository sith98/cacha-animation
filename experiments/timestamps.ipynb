# %%
import json
import os
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ## Testlauf Neupfarrplatz

# %%
# load by user json data
data = {}
for filename in os.listdir("../data/testlauf-neupfarrplatz/log-by-user"):
    with open("../data/testlauf-neupfarrplatz/log-by-user/" + filename) as f:
        data[filename.removesuffix(".json")] = json.load(f)

# %%
teams = data.keys()

# %%
# collect timestamps for each team
timestamps = {}
for team in teams:
    timestamps[team] = []
    for entry in data[team]:
        timestamps[team].append(entry['current_location']['timestamp'])

# %%
# plot timestamps using matplotlib
for team in teams:
    plt.scatter(timestamps[team], [team] * len(timestamps[team]), label=team)
plt.show()

# %%
# plot timestamps using plotly
fig = px.scatter()
for team in teams:
    fig.add_scatter(x=timestamps[team], y=[team] * len(timestamps[team]), mode='markers', name=team)
fig.show()

# %% [markdown]
# ## Hackaburg Campuswiese

# %%
# get team names
data_names = json.load(open("../data/hackaburg-campuswiese/log-export/team_activated.json"))
team_names = {}
for entry in data_names:
    team_names[entry['active_user']] = entry['team_name']
team_names
# Out:
# {'5fa28584-19d7-11ef-89a9-91251b4272d3': 'iso8601',
#  '3d759ca3-19d7-11ef-9bd3-e50b875d9764': 'Thomas',
#  '2a539389-19d7-11ef-afee-e50b875d9764': 'Sith',
#  '212797ed-19d7-11ef-9397-591084319220': 'Fresh & Fast'}

# %%
# load by user json data
data = {}
for filename in os.listdir("../data/hackaburg-campuswiese/log-by-user"):
    with open("../data/hackaburg-campuswiese/log-by-user/" + filename) as f:
        data[filename.removesuffix(".json")] = json.load(f)

# %%
teams = data.keys()

# %%
# collect timestamps for each team
timestamps = {}
for team in teams:
    timestamps[team] = []
    for entry in data[team]:
        timestamps[team].append(entry['current_location']['timestamp'])

# %%
# plot timestamps using matplotlib
for team in teams:
    plt.scatter(timestamps[team], [team] * len(timestamps[team]), label=team_names[team])
plt.show()

# %%
# plot timestamps using plotly
fig = px.scatter()
for team in teams:
    fig.add_scatter(x=timestamps[team], y=[team] * len(timestamps[team]), mode='markers', name=team_names[team])
fig.show()
